# %%
a = input("Enter email Id : ")
print(a.lower())
# Out:
# pranav

# %%
a = 12.5
print(round(12.6))
# Out:
# 13

# %%
num1 = int(input("Enter first number : "))
num2 = int(input("Enter second number : "))
if num1 > num2:
    print(num1, "is greater than", num2)
elif num1 == num2:
    print("Both numbers are equal")
elif num2 > num1:
    print(num2, "is greater than", num1)  
else:
    print("Invalid input")
# Out:
# 100 is greater than 12

# %%
round(12.6)
# Out:
# 13

# %%
num1 = int(input("Enter first number : "))
num2 = int(input("Enter second number : "))
num3 = int(input("Enter third number : "))

if num1 > num2 and num1 > num3:
    print(f"{num1} is greater than {num2} & {num3}")
elif num2 > num3 and num2 > num1:
    print(f"{num2} is greater than {num1} & {num3}")
elif num3 > num1 and num3 > num2:
    print(f"{num3} is greater than {num1} & {num2}")
elif num1 == num2 and num2 == num3:
    print("All three numbers are equal")  
else:
    print("Invalid Input")
# Out:
# 3 is greater than 1 & 2

# %%
a = int(input("Enter your age : ")) # 18+ only

if a > 17:
    b = input("Do you have a ticket? (yes/no) : ")
    if b.lower() == "yes":
        print("You can watch the movie") 
    elif b.lower() == "no":
        print("Ticket not available")
    else:
        print("Invalid input")
else:
    print("You are not eligible to watch the movie")
# Out:
# Ticket not available

# %%
Movies = ["Spider-Man", "Iron-Man", "Avengers", "Black Panther", "Thor", "Doctor Strange", "Captain America", "Guardians of the Galaxy", "Ant-Man"]
# Movies = {1 : "Spider-Man" , 2 : "Iron-Man", 3 : "Avengers", 4 : "Black Panther", 5 : "Thor", 6 : "Doctor Strange", 7 : "Captain America", 8 : "Guardians of the Galaxy", 9 : "Ant-Man"}
print ("Available Movies : ", Movies)
movie_id = int(input("Enter the movie id you want to watch : "))
movie_id = movie_id - 1
#if movie_id in Movies:
print("You have selected", Movies[movie_id])
#else:
 #   print("Invalid movie id")
# Out:
# Available Movies :  ['Spider-Man', 'Iron-Man', 'Avengers', 'Black Panther', 'Thor', 'Doctor Strange', 'Captain America', 'Guardians of the Galaxy', 'Ant-Man']
# You have selected Spider-Man
